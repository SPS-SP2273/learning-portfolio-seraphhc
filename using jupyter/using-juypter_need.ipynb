# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Need)</span></div>

# %% [markdown]
# # Code cell (python code)

# %%
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# # Markdown

# %% [markdown]
# The ships hung in the sky in much the same way that bricks don’t.

# %% [markdown]
# The ships *hung in the sky* in much the same way that **bricks don't.**<sup>1</sup><sub>QUOTE</sub>

# %% [markdown]
# ## - displaying code

# %% [markdown]
# `print('Hello World')`

# %% [markdown]
# #### it can also be a block of code

# %% [markdown]
# ```python
# print ('Hello World!')
# ```

# %% [markdown]
# ## - creating links (must include https://)

# %% [markdown]
# [SP2273 Website](http://sps.nus.edu.sg/sp2273)

# %% [markdown]
# ## - including images

# %% [markdown]
# ![](https://nus.edu.sg/images/default-source/base/logo.png)

# %% [markdown]
# ## - creating tables

# %% [markdown]
# |A   | B  |   C|
# |:---|:--:|---:|
# |a1  | b1 |  c1|
# |a2  | b2 |  c2|
# |a3  | b3 |  c3|

# %% [markdown]
# #### but this this troublesome, best to just create on excel and use table generator tools online to create tables

# %% [markdown]
# ## - creating lists

# %% [markdown]
# 1. apple
# 1. orange
# 1. pear

# %% [markdown]
# - apple
# - orange
# - pear

# %% [markdown]
# 1. apple
#    1. is red
#    1. or green
# 1. orange
#    1. is orange
# 1. pear
#    1. is green

# %% [markdown]
# ## - creating equations

# %% [markdown]
# $\sqrt{b^2-4ac}$

# %% [markdown]
# $$
# x = \dfrac{-b\pm \sqrt{b^2-4ac}}{2a}
# $$

# %% [markdown]
# math commands:

# %% [markdown]
# ![](![Screenshot 2024-01-21 at 7.39.05 PM.png](attachment:5d930a9f-2ed4-493f-8857-232d82d8f21f.png)

# %% [markdown]
# # Exercise 1

# %% [markdown]
# ## **Quadratic Equations**

# %% [markdown]
# ### **Introduction**
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/f/f8/Polynomialdeg2.svg/600px-Polynomialdeg2.svg.png)
# (*Image from the [Wikipedia page on Quadratic equations](https://en.wikipedia.org/wiki/Quadratic_equation)*)

# %% [markdown]
# The general form of a quadratic equation is:
# $$
# ax^2 + bx + c = 0
# $$

# %% [markdown]
# ### **Solutions**
# Provided $a \ne 0$, we can use an elementary algebraic method called [completing the square](https://en.wikipedia.org/wiki/Completing_the_square) to show that a quadratic equation has the following solution:
# $$
# x = \dfrac{-b\pm \sqrt{b^2-4ac}}{2a}
# $$

# %% [markdown]
# ### **Discriminant**
# The quantity $\Delta = b^2 -4ac$ is called the **discriminant** of the equation and decides the nature of its solutions. The table below shows the various possibilities.

# %% [markdown]
# |**Discriminant**         |**Roots**
# |:------------------------|------------------------------------|
# |$\Delta = b^2 -4ac = 0$  |A single solution of $-b/(2a)$      |
# |$\Delta = b^2 -4ac \gt 0$|Two distinct solutions              |
# |$\Delta = b^2 -4ac \lt 0$|No real solutions; both are complex.|

# %% [markdown]
# # Exercise 2

# %% [markdown]
# 1. It is like a file on Github that contains my learning portfolio (work done on jupyter).
# 1. changes
# 1. a commit allows a specific change to be recorded, and also allows a description about the change made
# 1. a push allows the commited changes on our local device to be shared with Github - cloud (share with others)
# 1. a pull allows changes in the cloud to be saved into our local device
# 1. GitHub desktop contains the repository on our local device while Github is the cloud version.
